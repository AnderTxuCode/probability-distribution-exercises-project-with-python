# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO
#Normal:
from scipy.stats import norm

def dnorm(x, mean=0, sd=1):
    return norm.pdf(x, loc=mean, scale=sd)

def pnorm(q, mean=0, sd=1):
    return norm.cdf(q, loc=mean, scale=sd)

def qnorm(p, mean=0, sd=1):
    return norm.ppf(p, loc=mean, scale=sd)

def rnorm(n, mean=0, sd=1):
    return norm.rvs(loc=mean, scale=sd, size=n)

np.random.seed(42)

print(f"Probabilidad de la densidad en x=2 para Normal(0,1): {dnorm(2, mean=0, sd=1)}")
print(f"Probabilidad que la Normal(0,1) coja valores menores a 2: {pnorm(2, mean=0, sd=1)}")
print(f"Que valores de la Normal(0,1) tenga la probabilidad acumulativa de 0.9? {qnorm(0.9, mean=0, sd=1)}")
print(f"Genera 2000 valores aleatorios de una distribución Normal(0,1): {rnorm(2000, mean=0, sd=1)}")

np.random.seed(42)

mean = 0
sd = 1
data = np.arange(-5, 5, 0.01)

pdf = dnorm(data, mean=mean, sd=sd)
cdf = pnorm(data, mean=mean, sd=sd)
ppf = qnorm(data, mean=mean, sd=sd)

fig, axis = plt.subplots(3, 1, figsize=(5, 7))

axis[0].plot(data, pdf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, ppf, "g-")

plt.tight_layout()
plt.show()
# Out:
# Probabilidad de la densidad en x=2 para Normal(0,1): 0.05399096651318806
# Probabilidad que la Normal(0,1) coja valores menores a 2: 0.9772498680518208
# Que valores de la Normal(0,1) tenga la probabilidad acumulativa de 0.9? 1.2815515655446004
# Genera 2000 valores aleatorios de una distribución Normal(0,1): [ 0.49671415 -0.1382643   0.64768854 ... -0.88187465 -0.16306696
#  -0.74490264]

# %%
from scipy.stats import uniform

def dunif(x, low=0, high=1):
    return uniform.pdf(x, loc=low, scale=high - low)

def punif(q, low=0, high=1):
    return uniform.cdf(q, loc=low, scale=high - low)

def qunif(p, low=0, high=1):
    return uniform.ppf(p, loc=low, scale=high - low)

def runif(n, low=0, high=1):
    return uniform.rvs(loc=low, scale=high - low, size=n)

print(f"Probabilidad de la densidad en x=2 para Uniforme(0,1): {dunif(2, low=low, high=high)}")
print(f"Probabilidad que la Uniforme(0,1) coja valores menores a 2: {punif(2, low=low, high=high)}")
print(f"Que valor de que la Uniforme(0,1) tenga la probabilidad acumulativa de 0.9? {qunif(0.9, low=low, high=high)}")
print(f"Genera 2000 valores aleatorios de una distribución Uniforme(0,1): {runif(2000, low=low, high=high)}")

np.random.seed(42)

low = 0
high = 1
data = np.arange(-5, 5, 0.01)

pmf = dunif(data, low=low, high=high)
cdf = punif(data, low=low, high=high)
ppf = qunif(cdf, low=low, high=high)

fig, axis = plt.subplots(3, 1, figsize=(5, 7))

axis[0].plot(data, pmf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, ppf, "g-")

plt.tight_layout()
plt.show()
# Out:
# Probabilidad de la densidad en x=2 para Uniforme(0,1): 0.0
# Probabilidad que la Uniforme(0,1) coja valores menores a 2: 1.0
# Que valor de que la Uniforme(0,1) tenga la probabilidad acumulativa de 0.9? 0.9
# Genera 2000 valores aleatorios de una distribución Uniforme(0,1): [0.37454012 0.95071431 0.73199394 ... 0.06895802 0.05705472 0.28218707]
